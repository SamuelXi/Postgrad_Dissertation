# %%
import pandas as pd
import matplotlib.pyplot as plt
import kabuki
# %matplotlib inline
import hddm
print(hddm.__version__)

# For later convergence check
import multiprocessing as mp
# Out:
# 0.8.0
# /Users/samuelxisun/opt/anaconda3/envs/pyHDDM/lib/python3.6/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %% [markdown]
# ## Two condition HDDM (z : trial_type)
# #### Load data and check data head
# ##### Use control.csv

# %%
# Load data from csv file into a NumPy structured array
dataCon = hddm.load_csv('./rt_dataframes/control.csv')
dataCon.head(10)
#check number of rows of data
#data.shape
# Out:
#              subjID      rt  win  trial_type  gain  loss  cert  gamble
# 0  27902f23b60a7b76  2238.0  1.0         102  14.0   0.0   6.0     1.0
# 1  27902f23b60a7b76  1924.0  1.0         101  15.0  -5.0   0.0     1.0
# 2  27902f23b60a7b76  1415.0  0.0         101  13.0  -3.0   0.0     1.0
# 3  27902f23b60a7b76  2014.0  1.0         102   8.0   0.0   3.0     1.0
# 4  27902f23b60a7b76  1082.0  1.0         102  12.0   0.0   6.0     1.0
# 5  27902f23b60a7b76  1223.0  1.0         101  12.0  -3.0   0.0     1.0
# 6  27902f23b60a7b76  1115.0  0.0         102  14.0   0.0   4.0     1.0
# 7  27902f23b60a7b76  1124.0  0.0         102  12.0   0.0   3.0     1.0
# 8  27902f23b60a7b76  1712.0  0.0         101  20.0  -8.0   0.0     1.0
# 9  27902f23b60a7b76  1345.0  0.0         102  12.0   0.0   4.0     1.0

# %% [markdown]
# ## Prep the data
# #### Changed the columns name allow hddm to pick up

# %%
dataCon = dataCon.rename(columns={'subjID'
: 
'subj_idx',
'gamble':
'response'})
dataCon['rt'] = dataCon['rt']/1000
dataCon.head(10)
# Out:
#            subj_idx     rt  win  trial_type  gain  loss  cert  response
# 0  27902f23b60a7b76  2.238  1.0         102  14.0   0.0   6.0       1.0
# 1  27902f23b60a7b76  1.924  1.0         101  15.0  -5.0   0.0       1.0
# 2  27902f23b60a7b76  1.415  0.0         101  13.0  -3.0   0.0       1.0
# 3  27902f23b60a7b76  2.014  1.0         102   8.0   0.0   3.0       1.0
# 4  27902f23b60a7b76  1.082  1.0         102  12.0   0.0   6.0       1.0
# 5  27902f23b60a7b76  1.223  1.0         101  12.0  -3.0   0.0       1.0
# 6  27902f23b60a7b76  1.115  0.0         102  14.0   0.0   4.0       1.0
# 7  27902f23b60a7b76  1.124  0.0         102  12.0   0.0   3.0       1.0
# 8  27902f23b60a7b76  1.712  0.0         101  20.0  -8.0   0.0       1.0
# 9  27902f23b60a7b76  1.345  0.0         102  12.0   0.0   4.0       1.0

# %%
#flip the error RTs to be negative
dataCon = hddm.utils.flip_errors(dataCon)
#plt the RTs grouped by participants
fig = plt.figure()
ax = fig.add_subplot(111, xlabel='RT', ylabel='count', title='Response time distribution(Control)')
for i, subj_data in dataCon.groupby('subj_idx'):
    subj_data.rt.hist(bins=20, histtype='step', ax=ax)
# plt.savefig('./fitting_results/HDDM/HDDM2C(separate)/rt_distribution(con).png')

# %% [markdown]
# ## Fitting the hierarchical model for one condition with no subject effects for Control participants

# %%
m = hddm.HDDM(dataCon,depends_on={'z': 'trial_type'}, include=('v', 'a', 'z', 't'))

m.find_starting_values()
m.sample(3000, burn=1000, dbname='./fitting_results/HDDM/HDDM2C(separate)/traces(2CCon_z)', db='pickle')
m.save('./fitting_results/HDDM/HDDM2C(separate)/model(2CCon_z)')
# Out:
# /Users/samuelxisun/opt/anaconda3/envs/pyHDDM/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 3000 of 3000 complete in 1052.2 sec

# %%
# plot posteriors
m.plot_posteriors(['a', 't', 'v', 'a_std', 'v_std','z', 'z_std','t_std'])
# Out:
# Plotting a
# Plotting a_std
# Plotting v
# Plotting v_std
# Plotting t
# Plotting t_std
# Plotting z(101)
# Plotting z(102)
# Plotting z_std

# %%
stats2Cz = m.gen_stats()
stats2Cz.to_csv('./fitting_results/HDDM/HDDM2C(separate)/HDDM2CCon_z.csv', sep=',')
stats2Cz[stats2Cz.index.isin(['a', 'a_std', 'v', 'v_std', 't', 't_std', 'z', 'z_std'])]
# Out:
#            mean        std       2.5q       25q       50q       75q     97.5q  \
# a       1.60711  0.0308626    1.54797   1.58594   1.60736   1.62714   1.66967
# a_std  0.227798  0.0254958   0.182607  0.210332  0.225799  0.243165  0.283498
# v      0.172959   0.066953  0.0410927  0.129105  0.172861  0.218345  0.302419
# v_std  0.484024  0.0482186   0.396826  0.450669  0.481733  0.516732  0.586864
# t      0.709862  0.0272811   0.658086  0.691039  0.709295  0.728036  0.764063
# t_std  0.213617  0.0210929   0.176159  0.198502  0.212712  0.228183  0.258069
# z_std  0.346693   0.019531   0.311039   0.33304  0.345861  0.359831  0.385802
#
#             mc err
# a      0.000826635
# a_std  0.000947411
# v       0.00172894
# v_std   0.00146821
# t      0.000738935
# t_std  0.000603031
# z_std  0.000640409

# %%
z_101, z_102 = m.nodes_db.node[['z(101)', 'z(102)']]
z_101_trace, z_102_trace = m.nodes_db.node[['z(101)', 'z(102)']]
hddm.analyze.plot_posterior_nodes([z_101, z_102])
plt.xlabel('Starting point (z)', fontsize = 14)
plt.ylabel('Posterior probability', fontsize = 14)
plt.title('Posterior of starting point for control group', fontsize = 12)
plt.savefig('./fitting_results/HDDM/HDDM2C(separate)/posterior_zCon(101,102).png')

# %%
m.dic
# Out:
# 16495.586416724662

# %% [markdown]
# ## Check for model convergence

# %%
# Set up models list to append results
models = list()

# %%
def fit_hddm_chain(data, chain_num):
    print(f'Fitting chain {chain_num}')
    m = hddm.HDDM(data,include=('v', 'a', 'z', 't'))
    m.find_starting_values()
    m.sample(3000, burn=1000, dbname = f'./fitting_results/HDDM/HDDM2C(separate)/chain2Cz_{chain_num}', db='pickle')
    m.save(f'./fitting_results/HDDM/HDDM2C(separate)/chain2CzANX_{chain_num}')
    print(f'Finished chain {chain_num}')
    return m

# %%
num_chains = 5
data_chains = [(dataCon,chain_num) for chain_num in range(num_chains)]

with mp.Pool(processes=num_chains) as pool:
    models = pool.starmap(fit_hddm_chain, data_chains)
print('Finished all chains')
# Out:
# Fitting chain 0Fitting chain 1
# Fitting chain 2
# Fitting chain 3
#
# Fitting chain 4
# /Users/samuelxisun/opt/anaconda3/envs/pyHDDM/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/samuelxisun/opt/anaconda3/envs/pyHDDM/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/samuelxisun/opt/anaconda3/envs/pyHDDM/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/samuelxisun/opt/anaconda3/envs/pyHDDM/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/samuelxisun/opt/anaconda3/envs/pyHDDM/lib/python3.6/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#
#  [-----------------99%----------------- ] 2996 of 3000 complete in 590.7 sec[-----------------100%-----------------] 3001 of 3000 complete in 591.1 sec[-----------------99%----------------- ] 2998 of 3000 complete in 591.2 sec[-----------------99%----------------- ] 2999 of 3000 complete in 591.2 sec[-----------------99%----------------- ] 2999 of 3000 complete in 591.2 secFinished chain 1
#  [-----------------100%-----------------] 3000 of 3000 complete in 591.6 sec[-----------------100%-----------------] 3000 of 3000 complete in 591.7 sec[-----------------100%-----------------] 3001 of 3000 complete in 591.8 secFinished chain 2
#
#
# Finished chain 3Finished chain 4Finished all chains

# %%
models
# Out:
# [<hddm.models.hddm_info.HDDM at 0x7fc8a1e51518>,
#  <hddm.models.hddm_info.HDDM at 0x7fc8a19e75f8>,
#  <hddm.models.hddm_info.HDDM at 0x7fc860be4160>,
#  <hddm.models.hddm_info.HDDM at 0x7fc8a1677780>,
#  <hddm.models.hddm_info.HDDM at 0x7fc8a1e362b0>]

# %%
results = hddm.analyze.gelman_rubin(models)
for key, value in results.items():
    print(f"{key}: {value}")
# Out:
# a: 0.9998341672807821
# a_std: 1.002630178591686
# a_subj.02535fcf7e16bb56: 1.0050259855419865
# a_subj.09ba82a2ca814481: 1.000275303816134
# a_subj.0abfc32a4d12c731: 1.0000705401535197
# a_subj.0b0a94c202d0b233: 0.9999499958171213
# a_subj.0d894551bc966608: 0.9998860530556932
# a_subj.15e0c065b2c11595: 1.0004523154159308
# a_subj.163b12703c8e5c3c: 1.0007518995292892
# a_subj.1bf86ff948486447: 0.9998839505092736
# a_subj.1cb976bac3a2016b: 1.0002934407577153
# a_subj.22d84796012679e8: 1.0001002584815777
# a_subj.247384e4eccc4f80: 1.0002070802085188
# a_subj.27902f23b60a7b76: 1.0004202027725944
# a_subj.296a71628065dfa8: 1.0002585101783574
# a_subj.371fb6652968f25f: 1.0016606007296815
# a_subj.3ddf191ed8c33c57: 1.0000250762796408
# a_subj.414f1040212a659b: 0.9998426892191762
# a_subj.46fd6e0b3b5c1df3: 0.9997883884162443
# a_subj.4866612e834a9f5a: 1.0011113474489957
# a_subj.4a43f99c56b2a634: 1.0001828706102809
# a_subj.4e3de1ed1c0d6103: 1.000152629838237
# a_subj.5497867d4afb5993: 1.0002080389258199
# a_subj.582ab220066afebc: 1.000381216014053
# a_subj.5b92bfe31aef1ef9: 1.000149343984888
# a_subj.6d04498f5bb2aefc: 0.9998928113015796
# a_subj.6df05dd94d8d774d: 1.000110278110189
# a_subj.6e0c43d93a4a361e: 0.9999588498238245
# a_subj.6ece121c0867568c: 1.0012999904434752
# a_subj.75da8965ce4f9b28: 1.001665622807041
# a_subj.77d9b25715656b19: 1.0001516166922497
# a_subj.7e158eee0bbe3c33: 0.9999393384271628
# a_subj.819c4ba6a036130b: 0.9999665667720157
# a_subj.820fed1432e2cffc: 1.0004827943430636
# a_subj.8364d0796dcecadf: 1.011897740857086
# a_subj.84397dc336c286b4: 1.000041039943258
# a_subj.88586c741f59e4d3: 1.000865301474249
# a_subj.8b79e9cd1e3a58e9: 1.0000993523689237
# a_subj.8e3374a0d50454e0: 0.9998202056157972
# t_subj.6ece121c0867568c: 1.0025416503375648
# t_subj.75da8965ce4f9b28: 1.0037431520676439
# t_subj.77d9b25715656b19: 1.000344696568936
# t_subj.7e158eee0bbe3c33: 1.0003603878692697
# t_subj.819c4ba6a036130b: 1.0005052399068466
# t_subj.820fed1432e2cffc: 1.0006318223205497
# t_subj.8364d0796dcecadf: 1.018047541381528
# t_subj.84397dc336c286b4: 1.0005629950778256
# t_subj.88586c741f59e4d3: 1.0010239813096165
# t_subj.8b79e9cd1e3a58e9: 1.00023959125204
# t_subj.8e3374a0d50454e0: 0.9999322764518644
# t_subj.8e531917bed03e00: 1.001015104844509
# t_subj.96b09fe2762bafab: 1.000055246311565
# t_subj.99bca86575635ced: 1.0003186809124074
# t_subj.9ead7cfe118211af: 1.0002046015658164
# t_subj.a0891b37b5b5d79d: 1.0002342777135818
# t_subj.a0b880b91c2982dc: 1.000746359321531
# t_subj.a751959dd7084c7b: 1.0000748290981465
# t_subj.ab06a32c33b7c594: 1.0003528403811803
# t_subj.b8d6cea15a548aa9: 0.9999693707806709
# t_subj.c012de0ccb49819f: 0.9998893415464688
# t_subj.c4ea8a11570e9599: 1.0007348580434288
# t_subj.c7ddb07dc740f9c1: 1.0002653022485335
# t_subj.c893ddb5f65f1a1c: 1.0004524628143874
# t_subj.d2bdb6ae89eb8aca: 1.0026595933110252
# t_subj.d33cbb234efa4296: 1.0008928160002601
# t_subj.d53b11bcaa0a2095: 1.0037278440786315
# t_subj.d9a79bcfee67b028: 1.0044956330741317
# t_subj.dfbeb23c419b6979: 1.0007882986473358
# t_subj.e03130e76a547e00: 1.0139932140901895
# t_subj.e35e2512791cd931: 1.0006591582235516
# t_subj.e7d525b0fc295332: 1.0014380763208537
# t_subj.e9ca70bcef834214: 1.0177686059848001
# t_subj.f98444c434d40f8b: 1.0008742041580503
# t_subj.fc7ef2c5b91399c2: 1.0001767197082323
# z_trans: 0.9998522026037381
# z_std: 1.0004118262592345
# z_subj_trans.02535fcf7e16bb56: 1.002256935881869
# z_subj_trans.09ba82a2ca814481: 0.9999109104361443
# z_subj_trans.0abfc32a4d12c731: 1.000220434372656
# z_subj_trans.0b0a94c202d0b233: 1.0000507202391267
# z_subj_trans.0d894551bc966608: 1.0001740321705093
# z_subj_trans.15e0c065b2c11595: 1.0007023242821937
# z_subj_trans.163b12703c8e5c3c: 0.9998621778972241
# z_subj_trans.1bf86ff948486447: 1.0006323511821142
# z_subj_trans.1cb976bac3a2016b: 1.0003412732100145
# z_subj_trans.22d84796012679e8: 1.0021400911570926
# z_subj_trans.247384e4eccc4f80: 1.0003229579710526
# z_subj_trans.27902f23b60a7b76: 1.0002880006904697
# z_subj_trans.296a71628065dfa8: 1.0012164529071312
# z_subj_trans.371fb6652968f25f: 1.0005696279029772
# z_subj_trans.3ddf191ed8c33c57: 1.0005484992077065
# z_subj_trans.414f1040212a659b: 1.000180311459159
# z_subj_trans.46fd6e0b3b5c1df3: 1.0014293329103794
# z_subj_trans.4866612e834a9f5a: 1.0003181449873693
# z_subj_trans.4a43f99c56b2a634: 0.9998029277800234
# z_subj_trans.4e3de1ed1c0d6103: 1.0036314105994997
# z_subj_trans.5497867d4afb5993: 1.0013354724166874
# z_subj_trans.582ab220066afebc: 1.0001680961985828
# z_subj_trans.5b92bfe31aef1ef9: 1.0007195294173965
# z_subj_trans.6d04498f5bb2aefc: 0.9997960396169466
# z_subj_trans.6df05dd94d8d774d: 1.001371762792394
# z_subj_trans.6e0c43d93a4a361e: 1.001221496724486
# z_subj_trans.6ece121c0867568c: 1.0000216001754985
# z_subj_trans.75da8965ce4f9b28: 0.9999835278878365
# z_subj_trans.77d9b25715656b19: 0.9998334813634872
# z_subj_trans.7e158eee0bbe3c33: 1.0004991798853227
# z_subj_trans.819c4ba6a036130b: 0.9998610091690815
# z_subj_trans.820fed1432e2cffc: 0.9999227872026409
# z_subj_trans.8364d0796dcecadf: 1.0027918409773744
# z_subj_trans.84397dc336c286b4: 1.0002263048579128
# z_subj_trans.88586c741f59e4d3: 1.0003116884576433
# z_subj_trans.8b79e9cd1e3a58e9: 1.000460604034596
# z_subj_trans.8e3374a0d50454e0: 1.0000688417805328
# z_subj_trans.8e531917bed03e00: 1.0015657711237784
# z_subj_trans.96b09fe2762bafab: 1.0001568351756351
# z_subj_trans.99bca86575635ced: 0.9998573836152899
# z_subj_trans.9ead7cfe118211af: 1.0016551189424028
# z_subj_trans.a0891b37b5b5d79d: 1.0016398976716874
# z_subj_trans.a0b880b91c2982dc: 0.9999656253358089
# z_subj_trans.a751959dd7084c7b: 1.000329259622542
# z_subj_trans.ab06a32c33b7c594: 1.0010272563068479
# z_subj_trans.b8d6cea15a548aa9: 1.0001407158903677
# z_subj_trans.c012de0ccb49819f: 0.9999012522367812
# z_subj_trans.c4ea8a11570e9599: 1.0004808977691446
# z_subj_trans.c7ddb07dc740f9c1: 0.999945595700118
# z_subj_trans.c893ddb5f65f1a1c: 1.0004705279612562
# z_subj_trans.d2bdb6ae89eb8aca: 1.000482750804683
# z_subj_trans.d33cbb234efa4296: 1.0017557449128438
# z_subj_trans.d53b11bcaa0a2095: 1.0008478830989656
# z_subj_trans.d9a79bcfee67b028: 1.0017292868318657
# z_subj_trans.dfbeb23c419b6979: 1.0004437558343144
# z_subj_trans.e03130e76a547e00: 1.0058245766588783
# z_subj_trans.e35e2512791cd931: 1.0003060221665534
# z_subj_trans.e7d525b0fc295332: 1.001030718882847
# z_subj_trans.e9ca70bcef834214: 1.0018135877254803
# z_subj_trans.f98444c434d40f8b: 1.001285752267676
# z_subj_trans.fc7ef2c5b91399c2: 1.0006813829843235

# %%
bigger_than_threshold = {}
smaller_than_threshold = {}
for key, value in results.items():
    if value > 1.1:
        bigger_than_threshold[key] = value
    elif value < 0.9:
        smaller_than_threshold[key] = value
print("Values bigger than the threshold:")
print(bigger_than_threshold)

print("\nValues smaller than the threshold:")
print(smaller_than_threshold)
# Out:
# Values bigger than the threshold:
# {}
#
# Values smaller than the threshold:
# {}

# %%
m.plot_posterior_predictive(figsize=(50, 70))
